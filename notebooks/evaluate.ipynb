# %%
from modeling.tree_models import build_random_forest
from modeling.base_model import train_model, predict_model, predict_proba_model
from modeling.evaluate import evaluate_classification, plot_confusion, plot_roc

# %%
# Build & train
model = build_random_forest(n_estimators=100, random_state=42)
model = train_model(model, X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 # Build & train
#       2 model = build_random_forest(n_estimators=100, random_state=42)
# ----> 3 model = train_model(model, X_train, y_train)
#
# NameError: name 'X_train' is not defined
