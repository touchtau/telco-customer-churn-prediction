# %% [markdown]
# # Exploratory Data Analysis (EDA) for Customer Churn
#
# This notebook is part of the Telco Customer Churn machine learning project.
#
# **EDA** phase is important in trying to understand the data and the relations between variables. It
# is a process for determining the patterns and properties of a given dataset.
#
# I will perform sta-
# tistical analysis to understand data patterns, distributions, and test hypothesis that might explain
# customer churn.
#
# Objectives: I will use descriptive statistics to summarize -
# • Distribution and range of data
# • Central Limit Theorem & sampling
# • Bootstraping - Apply the ‘Plug-in principle’ to complement CLT inferences
# • Confidence intervals
# • Hypothesis testing
# • Chi-squared tests for independence and categorical relationships
# • Analysis Of Variance (ANOVA) for multi-group comparison - check if there are statistcal
# difference between means of three or more groups.
# • Visualization for interpretation
# 0.3
# Initial Data Exploration
#
# import pandas as pd
# import warnings
# warnings.filterwarnings('ignore')
# #Displaying settings
# pd.set_option('display.max_columns', None)
# #Load the datasset
# df = pd.read_csv('../data/raw/telco-customer-churn-ibm.csv')
# print(f"Overview of dataset: \n")
# df.head()
